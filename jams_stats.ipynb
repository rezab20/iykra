# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
dfBefore = pd.read_csv('JamsBefore.csv')
dfBefore.head()
# Out:
#          date  flag  day  hour  minute              street  level  type  \
# 0  2019-06-05     0  2.0     6      55       Gatot Subroto      3     0
# 1  2019-06-05     0  2.0     7      26  Pelajar Pejuang 45      3     0
# 2  2019-06-05     0  2.0     7      28          Jalan Jawa      4     0
# 3  2019-06-05     0  2.0     7      39  Pelajar Pejuang 45      3     0
# 4  2019-06-05     0  2.0     7      40         Jalan Sunda      4     0
#
#    road_type       delay  speed_kmh  length  distance  count_data
# 0          7  119.142857  10.882857   510.0  1.131668           7
# 1          7  120.636364   9.958182   469.0  1.233164          11
# 2          1  384.750000   2.647500   296.5  1.716027           4
# 3          7   92.333333   8.795000   327.0  0.731429           6
# 4          7  109.500000   5.162500   194.0  1.313316           4

# %%
dfAfter = pd.read_csv('JamsAfter.csv')
dfAfter.head()
# Out:
#          date  flag  day  hour  minute              street  level  type  \
# 0  2021-01-30     1  5.0     6      48               Laswi      3     0
# 1  2021-01-30     1  5.0     6      52        WR Supratman      2     0
# 2  2021-01-30     1  5.0     7       4         Jalan Sunda      2     0
# 3  2021-01-30     1  5.0     7      10  Pelajar Pejuang 45      3     0
# 4  2021-01-30     1  5.0     7      29  Pelajar Pejuang 45      3     0
#
#    road_type      delay  speed_kmh  length  distance  count_data
# 0          7  69.846154   9.358462   330.0  0.897244          13
# 1          7  83.333333  18.913333   815.0  1.530744           3
# 2          7  61.625000  14.763750   584.0  1.281628           8
# 3          7  66.500000  23.055000   879.0  0.656896           2
# 4          7  77.000000  19.510000   781.0  0.979183           2

# %% [markdown]
# #### Belum ada alasan mengapa 5 dan 0 harus dihapus

# %%
dfAfter = dfAfter.loc[(dfAfter['level'] != 5) & (dfAfter['level'] != 0)]
dfBefore = dfBefore.loc[(dfBefore['level'] != 5) & (dfBefore['level'] != 0)]
len(dfAfter), len(dfBefore)
# Out:
# (61364, 79539)

# %% [markdown]
# #### Mencari jalan yang unik dan tidak
# unik = hanya terdapat di sebelum/sesudah <br>
# tidak = terdapat pada dua kondisi

# %%
streetB, streetA = dfBefore['street'].unique(), dfAfter['street'].unique()
uniqueB = set(streetB) - set(streetA)
uniqueA = set(streetA) - set(streetB)
sameStreet = set(streetB) & set(streetA)
len(uniqueB), len(uniqueA), len(sameStreet)
# Out:
# (71, 17, 127)

# %% [markdown]
# ### Data nama jalan terdapat di sebelum dan sesudah pembangunan

# %%
featuresGreater = ['speed_kmh']
listDifference = []
listMeanBefore = []
listMeanAfter = []
for feature in featuresGreater:
    dictDifference = {}
    dictBefore = {}
    dictAfter = {}
    for street in sameStreet:
        data1 = dfBefore[feature].loc[dfBefore['street'] == street]
        data2 = dfAfter[feature].loc[dfAfter['street'] == street]

        dictBefore[street] = data1.mean()
        dictAfter[street] = data2.mean()
        
        # Hitung variance menggunakan Levene
        statsiticsVar, pValVar = stats.levene(data1, data2)
        # Tolong dikoreksi pemberian equalFlag jika ada kesalahan
        equalFlag = True
        if pValVar >= 0.05:
            equalFlag = False
    
        # Ketika menggunakan greater maka hipotesis data 1 adalah lebih besar dibandingkan data 2
        statsiticsTtest, pValTtest = stats.ttest_ind(data1,data2, equal_var = equalFlag, alternative = 'greater')
        # Tolong dikoreksi pemberian nilai T/F pada kondisi ini
        if pValTtest <= 0.05:
            dictDifference[street] = False
        else:
            dictDifference[street] = True
        
    listDifference.append(dictDifference)
    listMeanBefore.append(dictBefore)
    listMeanAfter.append(dictAfter)

# %%
dfStatistics = pd.DataFrame(sameStreet, columns= ['street']).set_index('street')
dfStatistics.head(2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Pangarang, Tongkeng]

# %%
for i in range(len(featuresGreater)):
    sentences = str(featuresGreater[i])
    sentStatistics = sentences + '_hypothesis'
    sentBefore = sentences + '_before'
    sentAfter = sentences + '_after'
    tempDF1 = pd.DataFrame.from_dict(listDifference[i], orient = 'index',  columns = [sentStatistics])
    tempDF2 = pd.DataFrame.from_dict(listMeanBefore[i], orient = 'index',  columns = [sentBefore])
    tempDF3 = pd.DataFrame.from_dict(listMeanAfter[i], orient = 'index',  columns = [sentAfter])
    
    dfStatistics = dfStatistics.merge(tempDF1, left_index = True, right_index = True)
    dfStatistics = dfStatistics.merge(tempDF2, left_index = True, right_index = True)
    dfStatistics = dfStatistics.merge(tempDF3, left_index = True, right_index = True)

# %%
dfStatistics
# Out:
#                        speed_kmh_hypothesis  speed_kmh_before  speed_kmh_after
# Pangarang                              True          3.491538         3.169772
# Tongkeng                               True          8.592908         7.424602
# Jalan Natuna                          False          5.877292         4.979831
# Jalan Belitung                         True          8.820653        10.478368
# Terusan Gatot Subroto                  True          6.660075         7.895656
# ...                                     ...               ...              ...
# Talaga Bodas                          False         12.902312        11.868933
# Dalem Kaum                             True          6.096492         6.100738
# Lengkong Kecil                         True         12.940076        13.375821
# Jalan Cianjur                          True          5.372500         4.581490
# Pasirluyu Barat                        True          8.443077         8.172708
#
# [127 rows x 3 columns]

# %%
featuresLess = ['delay', 'length']
listDifference = []
listMeanBefore = []
listMeanAfter = []
for feature in featuresLess:
    dictDifference = {}
    dictBefore = {}
    dictAfter = {}
    for street in sameStreet:
        data1 = dfBefore[feature].loc[dfBefore['street'] == street]
        data2 = dfAfter[feature].loc[dfAfter['street'] == street]

        dictBefore[street] = data1.mean()
        dictAfter[street] = data2.mean()
        
        # Hitung variance menggunakan Levene
        statsiticsVar, pVal = stats.levene(data1, data2)
        # Tolong dikoreksi pemberian equalFlag jika ada kesalahan
        equalFlag = True
        if pValVar >= 0.05:
            equalFlag = False
    
        # Ketika menggunakan greater maka hipotesis data 1 adalah lebih besar dibandingkan data 2
        statsiticsTtest, pValTtest = stats.ttest_ind(data1,data2, equal_var = equalFlag, alternative = 'less')
        # Tolong dikoreksi pemberian nilai T/F pada konsisi ini
        if pValTtest <= 0.05:
            dictDifference[street] = False
        else:
            dictDifference[street] = True
        
    listDifference.append(dictDifference)
    listMeanBefore.append(dictBefore)
    listMeanAfter.append(dictAfter)

# %%
for i in range(len(featuresLess)):
    sentences = str(featuresLess[i])
    sentStatistics = sentences + '_hypothesis'
    sentBefore = sentences + '_before'
    sentAfter = sentences + '_after'
    tempDF1 = pd.DataFrame.from_dict(listDifference[i], orient = 'index',  columns = [sentStatistics])
    tempDF2 = pd.DataFrame.from_dict(listMeanBefore[i], orient = 'index',  columns = [sentBefore])
    tempDF3 = pd.DataFrame.from_dict(listMeanAfter[i], orient = 'index',  columns = [sentAfter])
    
    dfStatistics = dfStatistics.merge(tempDF1, left_index = True, right_index = True)
    dfStatistics = dfStatistics.merge(tempDF2, left_index = True, right_index = True)
    dfStatistics = dfStatistics.merge(tempDF3, left_index = True, right_index = True)

# %% [markdown]
# ### Data nama jalan terdapat di sebelum pembangunan tetapi tidak ada di setelah pembangunan dan kebalikannya

# %%
featuresGreater = ['speed_kmh']
listDifference = []
listMeanBefore = []
listMeanAfter = []
for feature in featuresGreater:
    dictDifference = {}
    dictBefore = {}
    dictAfter = {}
    data1 = dfBefore[feature].loc[dfBefore['street'].isin(uniqueB)]
    data2 = dfAfter[feature].loc[dfAfter['street'].isin(uniqueA)]
    print(data1.mean())
    dictBefore['Unique Street'] = data1.mean()
    dictAfter['Unique Street'] = data2.mean()

    # Hitung variance menggunakan Levene
    statsiticsVar, pValVar = stats.levene(data1, data2)
    # Tolong dikoreksi pemberian equalFlag jika ada kesalahan
    equalFlag = True
    if pValVar >= 0.05:
        equalFlag = False

    # Ketika menggunakan greater maka hipotesis data 1 adalah lebih besar dibandingkan data 2
    statsiticsTtest, pValTtest = stats.ttest_ind(data1,data2, equal_var = equalFlag, alternative = 'greater')
    # Tolong dikoreksi pemberian nilai T/F pada konsisi ini
    if pValTtest <= 0.05:
        dictDifference['Unique Street'] = False
    else:
        dictDifference['Unique Street'] = True
        
listDifference.append(dictDifference)
listMeanBefore.append(dictBefore)
listMeanAfter.append(dictAfter)
# Out:
# 5.501978058944391

# %%
tempStreet = ['Unique Street']
dfStatisticsTemp = pd.DataFrame(tempStreet, columns= ['street']).set_index('street')
dfStatisticsTemp.head(2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Unique Street]

# %%
for i in range(len(featuresGreater)):
    sentences = str(featuresGreater[i])
    sentStatistics = sentences + '_hypothesis'
    sentBefore = sentences + '_before'
    sentAfter = sentences + '_after'
    tempDF1 = pd.DataFrame.from_dict(listDifference[i], orient = 'index',  columns = [sentStatistics])
    tempDF2 = pd.DataFrame.from_dict(listMeanBefore[i], orient = 'index',  columns = [sentBefore])
    tempDF3 = pd.DataFrame.from_dict(listMeanAfter[i], orient = 'index',  columns = [sentAfter])
    
    dfStatisticsTemp = dfStatisticsTemp.merge(tempDF1, left_index = True, right_index = True)
    dfStatisticsTemp = dfStatisticsTemp.merge(tempDF2, left_index = True, right_index = True)
    dfStatisticsTemp = dfStatisticsTemp.merge(tempDF3, left_index = True, right_index = True)

# %%
dfStatisticsTemp
# Out:
#                speed_kmh_hypothesis  speed_kmh_before  speed_kmh_after
# street
# Unique Street                  True          5.501978         7.159593

# %%
featuresLess = ['delay', 'length']
listDifference = []
listMeanBefore = []
listMeanAfter = []
for feature in featuresLess:
    dictDifference = {}
    dictBefore = {}
    dictAfter = {}

    data1 = dfBefore[feature].loc[dfBefore['street'].isin(uniqueB)]
    data2 = dfAfter[feature].loc[dfAfter['street'].isin(uniqueA)]

    dictBefore['Unique Street'] = data1.mean()
    dictAfter['Unique Street'] = data2.mean()

    # Hitung variance menggunakan Levene
    statsiticsVar, pVal = stats.levene(data1, data2)
    # Tolong dikoreksi pemberian equalFlag jika ada kesalahan
    equalFlag = True
    if pValVar >= 0.05:
        equalFlag = False

    # Ketika menggunakan greater maka hipotesis data 1 adalah lebih besar dibandingkan data 2
    statsiticsTtest, pValTtest = stats.ttest_ind(data1,data2, equal_var = equalFlag, alternative = 'less')
    # Tolong dikoreksi pemberian nilai T/F pada konsisi ini
    if pValTtest <= 0.05:
        dictDifference['Unique Street'] = False
    else:
        dictDifference['Unique Street'] = True
        
    listDifference.append(dictDifference)
    listMeanBefore.append(dictBefore)
    listMeanAfter.append(dictAfter)

# %%
for i in range(len(featuresLess)):
    sentences = str(featuresLess[i])
    sentStatistics = sentences + '_hypothesis'
    sentBefore = sentences + '_before'
    sentAfter = sentences + '_after'
    tempDF1 = pd.DataFrame.from_dict(listDifference[i], orient = 'index',  columns = [sentStatistics])
    tempDF2 = pd.DataFrame.from_dict(listMeanBefore[i], orient = 'index',  columns = [sentBefore])
    tempDF3 = pd.DataFrame.from_dict(listMeanAfter[i], orient = 'index',  columns = [sentAfter])
    
    dfStatisticsTemp = dfStatisticsTemp.merge(tempDF1, left_index = True, right_index = True)
    dfStatisticsTemp = dfStatisticsTemp.merge(tempDF2, left_index = True, right_index = True)
    dfStatisticsTemp = dfStatisticsTemp.merge(tempDF3, left_index = True, right_index = True)

# %%
dfStatisticsTemp
# Out:
#                speed_kmh_hypothesis  speed_kmh_before  speed_kmh_after  \
# street
# Unique Street                  True          5.501978         7.159593
#
#                delay_hypothesis  delay_before  delay_after  length_hypothesis  \
# street
# Unique Street              True    128.906128   129.426964              False
#
#                length_before  length_after
# street
# Unique Street      258.91405     301.26912
